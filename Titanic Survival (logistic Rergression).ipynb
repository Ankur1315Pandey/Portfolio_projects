# %% [markdown]
# **LOGISTIC REGRESSIO (TITANIC SURVIVAL DATASET)**

# %% [markdown]
# **IMPORTING THE LIBRARY**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold,StratifiedKFold
from sklearn.metrics import confusion_matrix

# %% [markdown]
# **IMPORT THE DATASET**

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df)
# Out:
# 891

# %% [markdown]
# **DATA ANALYSIS aND EXPLORATORY DATA ANALYSIS**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.isnull(),annot=True,cmap ='Greens')
# Out:
# <Axes: >

# %%
(df.Age.isnull().sum()/len(df.Age))*100
# Out:
# 19.865319865319865

# %%
df.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
df.drop('Cabin', axis = 1,inplace=True )

# %%
df.Embarked.nunique()
# Out:
# 3

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female  38.0      0      0  113572  80.0      NaN
# 829  female  62.0      0      0  113572  80.0      NaN

# %%
df.loc[df.Pclass==1,"Embarked"].value_counts()
# Out:
# Embarked
# S    127
# C     85
# Q      2
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data = df, hue ='Embarked')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
df.loc[df.Pclass==2,"Embarked"].value_counts()
# Out:
# Embarked
# S    164
# C     17
# Q      3
# Name: count, dtype: int64

# %%
df.loc[df.Pclass==3,"Embarked"].value_counts()
# Out:
# Embarked
# S    353
# Q     72
# C     66
# Name: count, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.fillna(df.Age.mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Age.isnull().sum()
# Out:
# 0

# %%
plt.hist(df.Age)
# Out:
# (array([ 54.,  46., 177., 169., 117.,  70.,  45.,  23.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxenplot(df.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
df.Age.value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.shape
# Out:
# (712, 11)

# %%
df.Sex.value_counts().plot.bar(df.Sex, color='Red')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# Graph to find out survivav with respec to sex

# %%
sns.countplot(x='Survived',data = df , hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df.Pclass.value_counts().plot.bar(df.Pclass)
# Out:
# <Axes: xlabel='Pclass'>

# %%
sns.countplot(x='Survived',data = df , hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# **FEATURE SCALING**

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **ENCODING**

# %% [markdown]
# **Changing the categorical values into th numerical values**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
ndf = df.copy()

# %%
enc =LabelEncoder()
ndf.Sex = enc.fit_transform(ndf['Sex'])
ndf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
df.Age .astype(int)
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 885    39
# 886    27
# 887    19
# 889    26
# 890    32
# Name: Age, Length: 712, dtype: int64

# %% [markdown]
# changing Fare to two decimal places

# %%
df.Fare = round(df.Fare,2)
df.Fare
# Out:
# 0       7.25
# 1      71.28
# 2       7.92
# 3      53.10
# 4       8.05
#        ...
# 885    29.12
# 886    13.00
# 887    30.00
# 889    30.00
# 890     7.75
# Name: Fare, Length: 712, dtype: float64

# %% [markdown]
# using pandas get_dummies function for **one Hot Encoding**

# %%
newdf =df.copy()
newdf
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
newdf= pd.get_dummies(newdf['Embarked']).astype(int)

# %%
newdf.astype(int)
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 885  0  1  0
# 886  0  0  1
# 887  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [712 rows x 3 columns]

# %%
newdf.head()
# Out:
#    C  Q  S
# 0  0  0  1
# 1  1  0  0
# 2  0  0  1
# 3  0  0  1
# 4  0  0  1

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.concat([ndf,newdf],axis=1)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
n1df = df.drop(columns=['Name', 'Ticket','Embarked'])

# %%
n1df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S
# 0            1         0       3    1  22.0      1      0   7.2500  0  0  1
# 1            2         1       1    0  38.0      1      0  71.2833  1  0  0
# 2            3         1       3    0  26.0      0      0   7.9250  0  0  1
# 3            4         1       1    0  35.0      1      0  53.1000  0  0  1
# 4            5         0       3    1  35.0      0      0   8.0500  0  0  1

# %%
n1df.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.029526 -0.035609  0.024674  0.033681 -0.082704
# Survived        0.029526  1.000000 -0.356462 -0.536762 -0.082446 -0.015523
# Pclass         -0.035609 -0.356462  1.000000  0.150826 -0.365902  0.065187
# Sex             0.024674 -0.536762  0.150826  1.000000  0.099037 -0.106296
# Age             0.033681 -0.082446 -0.365902  0.099037  1.000000 -0.307351
# SibSp          -0.082704 -0.015523  0.065187 -0.106296 -0.307351  1.000000
# Parch          -0.011672  0.095265  0.023666 -0.249543 -0.187896  0.383338
# Fare            0.009655  0.266100 -0.552893 -0.182457  0.093143  0.139860
# C               0.008654  0.195673 -0.279194 -0.103611  0.038268 -0.046227
# Q              -0.027045 -0.048966  0.131989 -0.027256 -0.021693  0.051331
# S               0.004605 -0.159015  0.197831  0.109078 -0.025431  0.018968
#
#                 Parch      Fare         C         Q         S
# ...

# %%
sns.heatmap(n1df.corr())
# Out:
# <Axes: >

# %% [markdown]
# **FEATURE SELECTION**

# %%
x=n1df.iloc[:,2:]
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S
# 0         3    1  22.0      1      0   7.2500  0  0  1
# 1         1    0  38.0      1      0  71.2833  1  0  0
# 2         3    0  26.0      0      0   7.9250  0  0  1
# 3         1    0  35.0      1      0  53.1000  0  0  1
# 4         3    1  35.0      0      0   8.0500  0  0  1
# ..      ...  ...   ...    ...    ...      ... .. .. ..
# 885       3    0  39.0      0      5  29.1250  0  1  0
# 886       2    1  27.0      0      0  13.0000  0  0  1
# 887       1    0  19.0      0      0  30.0000  0  0  1
# 889       1    1  26.0      0      0  30.0000  1  0  0
# 890       3    1  32.0      0      0   7.7500  0  1  0
#
# [712 rows x 9 columns]

# %%
y=n1df.iloc[:,1]
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 712, dtype: int64

# %% [markdown]
# **CHOOSING THE MODEL**

# %%
from sklearn.ensemble import ExtraTreesClassifier
feat = ExtraTreesClassifier()
feat.fit(x,y)
# Out:
# ExtraTreesClassifier()

# %%
feat.feature_importances_
# Out:
# array([0.11399174, 0.272494  , 0.2702914 , 0.04491087, 0.04195818,
#        0.22770079, 0.01584596, 0.00287944, 0.00992763])

# %%
feat_imp = pd.Series(feat.feature_importances_,index =x.columns)
feat_imp.nlargest(10).plot(kind ='barh')
# Out:
# <Axes: >

# %% [markdown]
# **SPLIT THE DATA -CROSS VALIDATION**

# %%
skf = StratifiedKFold(n_splits = 5)
for train_index, test_index  in skf.split(x,y):
  x_train , x_test =x.iloc[train_index],x.iloc[test_index]
  y_train , y_test = y.iloc[train_index],y.iloc[test_index]

# %%
x_test
# Out:
#      Pclass  Sex   Age  SibSp  Parch     Fare  C  Q  S
# 712       1    1  48.0      1      0   52.000  0  0  1
# 716       1    0  38.0      0      0  227.525  1  0  0
# 717       2    0  27.0      0      0   10.500  0  0  1
# 720       2    0   6.0      0      1   33.000  0  0  1
# 723       2    1  50.0      0      0   13.000  0  0  1
# ..      ...  ...   ...    ...    ...      ... .. .. ..
# 885       3    0  39.0      0      5   29.125  0  1  0
# 886       2    1  27.0      0      0   13.000  0  0  1
# 887       1    0  19.0      0      0   30.000  0  0  1
# 889       1    1  26.0      0      0   30.000  1  0  0
# 890       3    1  32.0      0      0    7.750  0  1  0
#
# [142 rows x 9 columns]

# %%
y_test
# Out:
# 712    1
# 716    1
# 717    1
# 720    1
# 723    0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 142, dtype: int64

# %% [markdown]
# **TRAIN THE MODEL**

# %%
classifier = LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# **TEST THE MODEL**

# %%
y_pred = classifier.predict(x_test)

# Out:
#      Actual  predicted
# 712       1          0
# 716       1          1
# 717       1          1
# 720       1          1
# 723       0          0
# ..      ...        ...
# 885       0          0
# 886       0          0
# 887       1          1
# 889       1          1
# 890       0          0
#
# [142 rows x 2 columns]

# %%
final.corr()
# Out:
#              Actual  predicted
# Actual     1.000000   0.633349
# predicted  0.633349   1.000000

# %%
sns.heatmap(final.corr(), annot = True , cmap = 'Greens')
# Out:
# <Axes: >

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[73, 11],
#        [14, 44]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.823943661971831

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.87      0.84      0.85        87\n           1       0.76      0.80      0.78        55\n\n    accuracy                           0.82       142\n   macro avg       0.81      0.82      0.82       142\nweighted avg       0.83      0.82      0.82       142\n'
